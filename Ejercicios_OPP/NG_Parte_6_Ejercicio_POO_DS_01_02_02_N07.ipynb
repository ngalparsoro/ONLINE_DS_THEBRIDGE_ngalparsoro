# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:

    tipo = "Electrodomésticos"
    abierta = True

    def __init__(self, nombre, direccion, num_empleados, ventas_ultimos_3_meses):
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas_ultimos_3_meses = ventas_ultimos_3_meses

    def ventas_totales(self):
        """Devuelve la suma de las ventas de los últimos 3 meses."""
        return sum(self.ventas_ultimos_3_meses)

    def media_ventas_por_empleado(self):
        """Calcula la media de ventas por empleado."""
        return self.ventas_totales() / self.num_empleados

    def informacion(self):
        """Devuelve un string con el nombre y la dirección de la tienda."""
        return f"{self.nombre}, {self.direccion}"

    def ventas_ultimo_mes(self):
        """Devuelve las ventas del último mes (último elemento de la lista)."""
        return self.ventas_ultimos_3_meses[-1]

    def proyeccion_ventas(self, x):
        """Aplica un aumento a las ventas según la inversión x y actualiza el atributo."""
        if x < 1000:
            factor = 1.2
        else:
            factor = 1.5

        nuevas_ventas = [venta * factor for venta in self.ventas_ultimos_3_meses]
        self.ventas_ultimos_3_meses = nuevas_ventas
        return nuevas_ventas


# Crear tres tiendas con datos inventados
tienda1 = Tienda("ElectroCenter", "Avenida de la Constitución 123", 8, [12000, 13500, 14200])
tienda2 = Tienda("Hogar Digital", "Calle Mayor 45", 5, [8500, 9200, 9800])
tienda3 = Tienda("TecnoShop", "Avenida de América 78", 10, [20000, 21500, 22800])

# Comprobaciones en una de las tiendas (tienda1)
print("=== COMPROBACIONES EN TIENDA1 ===")
print(f"Nombre: {tienda1.nombre}")
print(f"Dirección: {tienda1.direccion}")
print(f"Nº empleados: {tienda1.num_empleados}")
print(f"Ventas últimos 3 meses: {tienda1.ventas_ultimos_3_meses}")
print(f"Ventas totales: {tienda1.ventas_totales()}")
print(f"Media de ventas por empleado: {tienda1.media_ventas_por_empleado():.2f}")
print(f"Información: {tienda1.informacion()}")
print(f"Ventas del último mes: {tienda1.ventas_ultimo_mes()}")

# Probar proyección con inversión < 1000
print("\n--- Proyección con inversión de 500€ ---")
nuevas_ventas = tienda1.proyeccion_ventas(500)
print(f"Nuevas ventas: {nuevas_ventas}")

# Calcular las ventas del último mes de todas las tiendas con un bucle for
print("\n=== VENTAS DEL ÚLTIMO MES DE TODAS LAS TIENDAS ===")
tiendas = [tienda1, tienda2, tienda3]
for tienda in tiendas:
    print(f"{tienda.nombre}: {tienda.ventas_ultimo_mes()} €")

# Imprimir los nombres de las tiendas cuya dirección lleve "Avenida"
print("\n=== TIENDAS CON 'Avenida' EN SU DIRECCIÓN ===")
for tienda in tiendas:
    if "Avenida" in tienda.direccion:
        print(tienda.nombre)
# Out:
# === COMPROBACIONES EN TIENDA1 ===
# Nombre: ElectroCenter
# Dirección: Avenida de la Constitución 123
# Nº empleados: 8
# Ventas últimos 3 meses: [12000, 13500, 14200]
# Ventas totales: 39700
# Media de ventas por empleado: 4962.50
# Información: ElectroCenter, Avenida de la Constitución 123
# Ventas del último mes: 14200
#
# --- Proyección con inversión de 500€ ---
# Nuevas ventas: [14400.0, 16200.0, 17040.0]
#
# === VENTAS DEL ÚLTIMO MES DE TODAS LAS TIENDAS ===
# ElectroCenter: 17040.0 €
# Hogar Digital: 9800 €
# TecnoShop: 22800 €
#
# === TIENDAS CON 'Avenida' EN SU DIRECCIÓN ===
# ElectroCenter
# TecnoShop

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    """Clase que representa a un perro con sus características básicas y comportamientos. """

    # Atributos comunes a todos los perros
    patas = 4
    orejas = 2
    ojos = 2

    def __init__(self, raza, pelo="Marrón", dueno=None):
        """Constructor de la clase Perro."""
        self.raza = raza
        self.pelo = pelo
        self.dueno = dueno
        self.velocidad = 0  # Por defecto, el perro está parado

    def andar(self, aumento_velocidad):
        """Aumenta la velocidad del perro."""
        self.velocidad += aumento_velocidad

    def parar(self):
        """Detiene al perro, estableciendo su velocidad a 0."""
        self.velocidad = 0

    def ladrar(self, mensaje):
        """Devuelve un ladrido seguido del mensaje proporcionado."""
        return f"GUAU! {mensaje}"

# 1. Crear un objeto de tipo Perro sin dueño
mi_perro = Perro("Labrador")

# 2. Comprobar que están bien todos sus atributos
print(f"Raza: {mi_perro.raza}")
print(f"Pelo: {mi_perro.pelo}")
print(f"Dueño: {mi_perro.dueno}")
print(f"Velocidad inicial: {mi_perro.velocidad}")
print(f"Patas: {mi_perro.patas}")
print(f"Orejas: {mi_perro.orejas}")
print(f"Ojos: {mi_perro.ojos}")

# 3. Probar que ande y comprobar su velocidad
print(f"Velocidad antes de andar: {mi_perro.velocidad}")
mi_perro.andar(5)
print(f"Velocidad después de andar (+5): {mi_perro.velocidad}")
mi_perro.andar(3)
print(f"Velocidad después de andar (+3 más): {mi_perro.velocidad}")

# 4. Pararlo
mi_perro.parar()
print(f"Velocidad después de parar: {mi_perro.velocidad}")

# 5. Probar el método ladrar 
print(mi_perro.ladrar("Quiero comer"))
# Out:
# Raza: Labrador
# Pelo: Marrón
# Dueño: None
# Velocidad inicial: 0
# Patas: 4
# Orejas: 2
# Ojos: 2
# Velocidad antes de andar: 0
# Velocidad después de andar (+5): 5
# Velocidad después de andar (+3 más): 8
# Velocidad después de parar: 0
# GUAU! Quiero comer
